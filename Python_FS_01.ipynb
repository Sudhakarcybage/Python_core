# %%
name1='anand'
print(name1)
name="anand"
print(name)
#1name="raju" # variable name should not start with number
#print(1name)
#first name= "sudha"  #variable name should not have space
#print(first name)
#name@ = "vachana" # variable name should not have special characters
print(name)
fullname= "kiran reddy"
print(fullname) # it print as it is
print(fullname.title()) # to print first charactor in capitol
print(fullname.upper()) #to print all the letters in cap
print(fullname.lower()) # to print all the letters in lower
a=2
b=3
c=a+b
print(c)
print(type(a))
print(type(fullname))

print()
print()
# Out:
# anand
# anand
# anand
# kiran reddy
# Kiran Reddy
# KIRAN REDDY
# kiran reddy
# 5
# <class 'int'>
# <class 'str'>
