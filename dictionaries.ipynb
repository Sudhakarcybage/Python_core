# %%
# I want to create a alien game

alien = {"color": "green", "points": 5}
print(alien)
print(type(alien))
type(alien)
#start position
alien["start_position"] = "level1"
print(alien)
var = alien["color"]
print(alien["start_position"])
print(alien)

user_account = {"username": "codetraining01", "Username": "code", "dob": "12/01/2020", "password": "pwd" }
print(user_account)

del user_account["username"]
print(user_account)
# not possible we have to use key value only
#del user_account["code"]
#print(user_account)
#Implimentation of the for loop on top of dictionary
# {'color': 'green', 'points': 5, 'start_position': 'level1'}

for k, v in alien.items():
    print(f"Key value: {k}\nValue: {v}\n")

name = "sudha"
print("Hello " +name)
print(f"Hello {name}!")
# Out:
# {'color': 'green', 'points': 5}
# <class 'dict'>
# {'color': 'green', 'points': 5, 'start_position': 'level1'}
# level1
# {'color': 'green', 'points': 5, 'start_position': 'level1'}
# {'username': 'codetraining01', 'Username': 'code', 'dob': '12/01/2020', 'password': 'pwd'}
# {'Username': 'code', 'dob': '12/01/2020', 'password': 'pwd'}
# Key value: color
# Value: green
#
# Key value: points
# Value: 5
#
# Key value: start_position
# Value: level1
#
# Hello sudha
# Hello sudha!
