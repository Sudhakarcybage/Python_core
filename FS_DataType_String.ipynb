# %%
# Introduction to f strings
# f"custom message, {placeholder} custom message 2 {ph2} {ph3}"
firstname = "kiran"
lastname = "reddy"
# I need to get full name
fullname = f"{firstname} {lastname}"
print(fullname)
print(fullname.title())
# o/p Kiran Reddy
# Adding white spaces to string
print("Favourite_prog_lang:pythonc++javacswiftjavascript")
#o/p Favourite_prog_lang:pythonc++javacswiftjavascript
#\n new line delimeter
print("Favourite_prog_lang:\n\tpython\nc++\njava\nc\nswift\njavascript")
#o/p Favourite_prog_lang:
#   python
#c++
#java
#c
#swift
#javascript
#   \t tab delimeter
# removing white spaces from the string
name = " python"
print(name)
name2 = "python "
print(name2)
#name.lstrip()
print(name.lstrip())
print(name2.rstrip())
name3 = "   python      "
print(name3.strip())
# Out:
# kiran reddy
# Kiran Reddy
# Favourite_prog_lang:pythonc++javacswiftjavascript
# Favourite_prog_lang:
# 	python
# c++
# java
# c
# swift
# javascript
#  python
# python
# python
# python
# python
